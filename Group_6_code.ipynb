# %%
import numpy as np
import pandas as pd
df_1=pd.read_csv('Time_data.csv',usecols=['Sl.No','Lane','VehicleType','Entry','Exit'])
df_2=pd.read_csv('Area_data.csv')

# %%
def diff(a,b):
    return a-b
df_1.insert(5,column='TravelTime',value=diff(df_1['Exit'],df_1['Entry']))

# %%
def speed(a):
    return 223.2/a
df_1.insert(6,column='Speed(kmph)',value=speed(df_1['TravelTime']))

# %%
def interval(a):
    return a*300
df_1.insert(7,column='Time Interval',value=interval(df_1['Sl.No']))
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
#       Time Interval
# 0               300
# ...

# %%
new_col=['CumulativeEntryFlow']
df_1['CumulativeEntryFlow'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Entry'][j] <= df_1['Time Interval'][i]:
           df_1['CumulativeEntryFlow'][i] = df_1['CumulativeEntryFlow'][i]+1
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\199317439.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['CumulativeEntryFlow'][i] = df_1['CumulativeEntryFlow'][i]+1
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['CumulativeExitFlow']
df_1['CumulativeExitFlow'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i]:
           df_1['CumulativeExitFlow'][i] = df_1['CumulativeExitFlow'][i]+1
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\12563857.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['CumulativeExitFlow'][i] = df_1['CumulativeExitFlow'][i]+1
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['EntryFlow/Interval']
df_1['EntryFlow/Interval'] = df_1['CumulativeEntryFlow'].shift(0).diff()
df_1['EntryFlow/Interval'][0] = 52
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\3961037468.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['EntryFlow/Interval'][0] = 52
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# ...

# %%
new_col=['ExitFlow/Interval']
df_1['ExitFlow/Interval'] = df_1['CumulativeExitFlow'].shift(0).diff()
df_1['ExitFlow/Interval'][0] = 49
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1208682577.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['ExitFlow/Interval'][0] = 49
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# ...

# %%
new_col=['Travel Time in one minute']
df_1['Travel Time in one minute'] = 0.0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i]:
           df_1['Travel Time in one minute'][i] = df_1['Travel Time in one minute'][i]+df_1['TravelTime'][j]
        else:
            break
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\3595684971.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Travel Time in one minute'][i] = df_1['Travel Time in one minute'][i]+df_1['TravelTime'][j]
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['Travel Time in one minute(interval wise)']
df_1['Travel Time in one minute(interval wise)'] = df_1['Travel Time in one minute'].shift(0).diff()
df_1['Travel Time in one minute(interval wise)'][0] = df_1['Travel Time in one minute'][0]
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\871240178.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Travel Time in one minute(interval wise)'][0] = df_1['Travel Time in one minute'][0]
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
def Avg(a,b):
    return a/b
df_1.insert(14,column='Avg Travel Time in one minute',value=Avg(df_1['Travel Time in one minute(interval wise)'],df_1['ExitFlow/Interval']))
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
# ...

# %%
def sms(a):
    return 223.2/a
df_1.insert(15,column='SMS',value=sms(df_1['Avg Travel Time in one minute']))
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
# ...

# %%
def EFPH(a):
    return a*60
df_1.insert(16,column='Exit Flow Per Hour',value=EFPH(df_1['ExitFlow/Interval']))
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
# ...

# %%
new_col=['Small Car']
df_1['Small Car'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==1:
           df_1['Small Car'][i] = df_1['Small Car'][i]+1
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1251358351.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Small Car'][i] = df_1['Small Car'][i]+1
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# ...

# %%
new_col=['Big Car']
df_1['Big Car'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==2:
           df_1['Big Car'][i] = df_1['Big Car'][i]+1
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2633847928.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Big Car'][i] = df_1['Big Car'][i]+1
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# ...

# %%
new_col=['Two Wheeler']
df_1['Two Wheeler'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==3:
           df_1['Two Wheeler'][i] = df_1['Two Wheeler'][i]+1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1675739164.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Two Wheeler'][i] = df_1['Two Wheeler'][i]+1

# %%
new_col=['LCV']
df_1['LCV'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==4:
           df_1['LCV'][i] = df_1['LCV'][i]+1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2948836817.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['LCV'][i] = df_1['LCV'][i]+1

# %%
new_col=['Bus']
df_1['Bus'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==5:
           df_1['Bus'][i] = df_1['Bus'][i]+1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\3659095477.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Bus'][i] = df_1['Bus'][i]+1

# %%
new_col=['Single Axle']
df_1['Single Axle'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==6:
           df_1['Single Axle'][i] = df_1['Single Axle'][i]+1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1913037099.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Single Axle'][i] = df_1['Single Axle'][i]+1

# %%
new_col=['Multi Axle']
df_1['Multi Axle'] = 0
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==7:
           df_1['Multi Axle'][i] = df_1['Multi Axle'][i]+1
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2202649595.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Multi Axle'][i] = df_1['Multi Axle'][i]+1
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['Small Car interval wise']
df_1['Small Car interval wise'] = df_1['Small Car'].shift(0).diff()
df_1['Small Car interval wise'][0] = 8
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\829094114.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Small Car interval wise'][0] = 8

# %%
new_col=['Big Car interval wise']
df_1['Big Car interval wise'] = df_1['Big Car'].shift(0).diff()
df_1['Big Car interval wise'][0] = 8
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1809023534.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Big Car interval wise'][0] = 8

# %%
new_col=['Two Wheeler interval wise']
df_1['Two Wheeler interval wise'] = df_1['Two Wheeler'].shift(0).diff()
df_1['Two Wheeler interval wise'][0] = 26
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\633624770.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Two Wheeler interval wise'][0] = 26

# %%
new_col=['LCV interval wise']
df_1['LCV interval wise'] = df_1['LCV'].shift(0).diff()
df_1['LCV interval wise'][0] = 1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\3105204274.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['LCV interval wise'][0] = 1

# %%
new_col=['Bus interval wise']
df_1['Bus interval wise'] = df_1['Bus'].shift(0).diff()
df_1['Bus interval wise'][0] = 2
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\823420271.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Bus interval wise'][0] = 2

# %%
new_col=['Single Axle interval wise']
df_1['Single Axle interval wise'] = df_1['Single Axle'].shift(0).diff()
df_1['Single Axle interval wise'][0] = 3
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\443395006.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Single Axle interval wise'][0] = 3

# %%
new_col=['Multi Axle interval wise']
df_1['Multi Axle interval wise'] = df_1['Multi Axle'].shift(0).diff()
df_1['Multi Axle interval wise'][0] = 1
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2409129951.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Multi Axle interval wise'][0] = 1
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# ...

# %%
new_col=['Cumulative Speed of Small Car']
df_1['Cumulative Speed of Small Car'] = 0.000
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==1:
           df_1['Cumulative Speed of Small Car'][i] = df_1['Cumulative Speed of Small Car'][i]+df_1['Speed(kmph)'][j]
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\673652128.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Small Car'][i] = df_1['Cumulative Speed of Small Car'][i]+df_1['Speed(kmph)'][j]
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['Cumulative Speed of Big Car']
df_1['Cumulative Speed of Big Car'] = 0.000
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==2:
           df_1['Cumulative Speed of Big Car'][i] = df_1['Cumulative Speed of Big Car'][i]+df_1['Speed(kmph)'][j]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1515082998.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Big Car'][i] = df_1['Cumulative Speed of Big Car'][i]+df_1['Speed(kmph)'][j]

# %%
new_col=['Cumulative Speed of Two Wheeler']
df_1['Cumulative Speed of Two Wheeler'] = 0.000
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==3:
           df_1['Cumulative Speed of Two Wheeler'][i] = df_1['Cumulative Speed of Two Wheeler'][i]+df_1['Speed(kmph)'][j]
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2659255680.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Two Wheeler'][i] = df_1['Cumulative Speed of Two Wheeler'][i]+df_1['Speed(kmph)'][j]
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['Cumulative Speed of LCV']
df_1['Cumulative Speed of LCV'] = 0.000
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==4:
           df_1['Cumulative Speed of LCV'][i] = df_1['Cumulative Speed of LCV'][i]+df_1['Speed(kmph)'][j]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2136344422.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of LCV'][i] = df_1['Cumulative Speed of LCV'][i]+df_1['Speed(kmph)'][j]

# %%
new_col=['Cumulative Speed of Bus']
df_1['Cumulative Speed of Bus'] = 0.000
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==5:
           df_1['Cumulative Speed of Bus'][i] = df_1['Cumulative Speed of Bus'][i]+df_1['Speed(kmph)'][j]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\3776409605.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Bus'][i] = df_1['Cumulative Speed of Bus'][i]+df_1['Speed(kmph)'][j]

# %%
new_col=['Cumulative Speed of Single Axle']
df_1['Cumulative Speed of Single Axle'] = 0.000
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==6:
           df_1['Cumulative Speed of Single Axle'][i] = df_1['Cumulative Speed of Single Axle'][i]+df_1['Speed(kmph)'][j]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2737126937.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Single Axle'][i] = df_1['Cumulative Speed of Single Axle'][i]+df_1['Speed(kmph)'][j]

# %%
new_col=['Cumulative Speed of Multi Axle']
df_1['Cumulative Speed of Multi Axle'] = 0.000
for i in range(87):
    for j in range(len(df_1)):
        if df_1['Exit'][j] <= df_1['Time Interval'][i] and df_1['VehicleType'][j]==7:
           df_1['Cumulative Speed of Multi Axle'][i] = df_1['Cumulative Speed of Multi Axle'][i]+df_1['Speed(kmph)'][j]
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2073025242.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Multi Axle'][i] = df_1['Cumulative Speed of Multi Axle'][i]+df_1['Speed(kmph)'][j]
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['Cumulative Speed of Small Car interval wise']
df_1['Cumulative Speed of Small Car interval wise'] = df_1['Cumulative Speed of Small Car'].shift(0).diff()
df_1['Cumulative Speed of Small Car interval wise'][0] = df_1['Cumulative Speed of Small Car'][0]
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\3903061536.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Small Car interval wise'][0] = df_1['Cumulative Speed of Small Car'][0]
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
new_col=['Cumulative Speed of Big Car interval wise']
df_1['Cumulative Speed of Big Car interval wise'] = df_1['Cumulative Speed of Big Car'].shift(0).diff()
df_1['Cumulative Speed of Big Car interval wise'][0] = df_1['Cumulative Speed of Big Car'][0]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1453818695.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Big Car interval wise'][0] = df_1['Cumulative Speed of Big Car'][0]

# %%
new_col=['Cumulative Speed of Two Wheeler interval wise']
df_1['Cumulative Speed of Two Wheeler interval wise'] = df_1['Cumulative Speed of Two Wheeler'].shift(0).diff()
df_1['Cumulative Speed of Two Wheeler interval wise'][0] = df_1['Cumulative Speed of Two Wheeler'][0]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1492944397.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Two Wheeler interval wise'][0] = df_1['Cumulative Speed of Two Wheeler'][0]

# %%
new_col=['Cumulative Speed of LCV interval wise']
df_1['Cumulative Speed of LCV interval wise'] = df_1['Cumulative Speed of LCV'].shift(0).diff()
df_1['Cumulative Speed of LCV interval wise'][0] = df_1['Cumulative Speed of LCV'][0]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2253628964.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of LCV interval wise'][0] = df_1['Cumulative Speed of LCV'][0]

# %%
new_col=['Cumulative Speed of Bus interval wise']
df_1['Cumulative Speed of Bus interval wise'] = df_1['Cumulative Speed of Bus'].shift(0).diff()
df_1['Cumulative Speed of Bus interval wise'][0] = df_1['Cumulative Speed of Bus'][0]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\3577621054.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Bus interval wise'][0] = df_1['Cumulative Speed of Bus'][0]

# %%
new_col=['Cumulative Speed of Single Axle interval wise']
df_1['Cumulative Speed of Single Axle interval wise'] = df_1['Cumulative Speed of Single Axle'].shift(0).diff()
df_1['Cumulative Speed of Single Axle interval wise'][0] = df_1['Cumulative Speed of Single Axle'][0]
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\920901017.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Single Axle interval wise'][0] = df_1['Cumulative Speed of Single Axle'][0]

# %%
new_col=['Cumulative Speed of Multi Axle interval wise']
df_1['Cumulative Speed of Multi Axle interval wise'] = df_1['Cumulative Speed of Multi Axle'].shift(0).diff()
df_1['Cumulative Speed of Multi Axle interval wise'][0] = df_1['Cumulative Speed of Multi Axle'][0]
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\1299606461.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['Cumulative Speed of Multi Axle interval wise'][0] = df_1['Cumulative Speed of Multi Axle'][0]
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# ...

# %%
def avg_speed_of_veh_5min(a,b):
    return a/b
df_1.insert(45,column='Avg Speed of Small Car',value=avg_speed_of_veh_5min(df_1['Cumulative Speed of Small Car interval wise'],df_1['Small Car interval wise']))
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
# ...

# %%
df_1.insert(46,column='Avg Speed of Big Car',value=avg_speed_of_veh_5min(df_1['Cumulative Speed of Big Car interval wise'],df_1['Big Car interval wise']))
df_1.insert(47,column='Avg Speed of Two Wheeler',value=avg_speed_of_veh_5min(df_1['Cumulative Speed of Two Wheeler interval wise'],df_1['Two Wheeler interval wise']))
df_1.insert(48,column='Avg Speed of LCV',value=avg_speed_of_veh_5min(df_1['Cumulative Speed of LCV interval wise'],df_1['LCV interval wise']))
df_1.insert(49,column='Avg Speed of Bus',value=avg_speed_of_veh_5min(df_1['Cumulative Speed of Bus interval wise'],df_1['Bus interval wise']))
df_1.insert(50,column='Avg Speed of Single Axle',value=avg_speed_of_veh_5min(df_1['Cumulative Speed of Single Axle interval wise'],df_1['Single Axle interval wise']))
df_1.insert(51,column='Avg Speed of Multi Axle',value=avg_speed_of_veh_5min(df_1['Cumulative Speed of Multi Axle interval wise'],df_1['Multi Axle interval wise']))

# %%
df_1 = df_1.fillna(0, limit=87)
df_1
def PCU(a,b):
    return (a/b)/5.36
df_1.insert(52,column='Small Car PCU',value=PCU(df_1['Avg Speed of Small Car'],df_1['Avg Speed of Small Car'])*5.36)
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
# ...

# %%
df_1.insert(53,column='Big Car PCU',value=PCU(df_1['Avg Speed of Small Car'],df_1['Avg Speed of Big Car'])*8.11)
df_1.insert(54,column='Two Wheeler PCU',value=PCU(df_1['Avg Speed of Small Car'],df_1['Avg Speed of Two Wheeler'])*1.2)
df_1.insert(55,column='LCV PCU',value=PCU(df_1['Avg Speed of Small Car'],df_1['Avg Speed of LCV'])*12.81)
df_1.insert(56,column='Bus PCU',value=PCU(df_1['Avg Speed of Small Car'],df_1['Avg Speed of Bus'])*24.54)
df_1.insert(57,column='Single Axle PCU',value=PCU(df_1['Avg Speed of Small Car'],df_1['Avg Speed of Single Axle'])*17.63)
df_1.insert(58,column='Multi Axle PCU',value=PCU(df_1['Avg Speed of Small Car'],df_1['Avg Speed of Multi Axle'])*17.63)
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
# ...

# %%
cols = ['Small Car PCU','Big Car PCU','Two Wheeler PCU','LCV PCU','Bus PCU','Single Axle PCU','Multi Axle PCU']
for i in range(87):
    for j in cols:
        if df_1[j][i] == np.inf:
            df_1[j][i] = 0
df_1
# Out:
# C:\Users\Rushitha.DESKTOP-1K8KA5S\AppData\Local\Temp\ipykernel_31632\2516745450.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[j][i] = 0
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# ...

# %%
new_col=['Final PCU per 5min']
df_1['Final PCU per 5min'] = df_1['Small Car PCU']*df_1['Small Car interval wise'] + df_1['Big Car PCU']*df_1['Big Car interval wise'] + df_1['Two Wheeler PCU']*df_1['Two Wheeler interval wise'] + df_1['LCV PCU']*df_1['LCV interval wise'] + df_1['Bus PCU']*df_1['Bus interval wise']+df_1['Single Axle PCU']*df_1['Single Axle interval wise']+df_1['Multi Axle PCU']*df_1['Multi Axle interval wise']
df_1
# Out:
#       Sl.No  Lane  VehicleType     Entry      Exit  TravelTime  Speed(kmph)  \
# 0         1     1            3      0.93      4.37        3.44    64.883721
# 1         2     1            3     10.77     16.27        5.50    40.581818
# 2         3     1            3     16.33     21.97        5.64    39.574468
# 3         4     1            3     32.20     36.37        4.17    53.525180
# 4         5     1            4     34.20     41.17        6.97    32.022956
# ...     ...   ...          ...       ...       ...         ...          ...
# 4739   4740     1            1  25951.52  25957.40        5.88    37.959184
# 4740   4741     1            3  25959.32  25965.92        6.60    33.818182
# 4741   4742     1            3  25960.28  25966.36        6.08    36.710526
# 4742   4743     1            1  25963.48  25970.92        7.44    30.000000
# 4743   4744     1            3  25972.08  25979.24        7.16    31.173184
#
# ...

# %%
df_1.to_csv('Final_Output.csv')

# %%
final_df = pd.DataFrame()
final_df['PCU per 5 min'] = df_1['Final PCU per 5min']
final_df['Total PCU per hour'] = df_1['Final PCU per 5min']*12
final_df['SMS'] = df_1['SMS']
final_df['Density'] = final_df['Total PCU per hour']/final_df['SMS']
final_df['Flow'] = df_1['Exit Flow Per Hour']
final_df
# Out:
#       PCU per 5 min  Total PCU per hour        SMS    Density    Flow
# 0         84.860302         1018.323621  35.658440  28.557717  2940.0
# 1         32.099594          385.195124  43.354662   8.884745  2040.0
# 2         95.172751         1142.073017  35.714241  31.978085  3060.0
# 3         92.455892         1109.470702  41.358863  26.825464  2880.0
# 4         48.562521          582.750258  46.554133  12.517691  2580.0
# ...             ...                 ...        ...        ...     ...
# 4739            NaN                 NaN        NaN        NaN     0.0
# 4740            NaN                 NaN        NaN        NaN     0.0
# 4741            NaN                 NaN        NaN        NaN     0.0
# 4742            NaN                 NaN        NaN        NaN     0.0
# 4743            NaN                 NaN        NaN        NaN     0.0
#
# [4744 rows x 5 columns]

# %%
final_df.to_csv('Final_Output2.csv')
